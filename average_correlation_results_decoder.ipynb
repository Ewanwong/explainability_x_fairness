# %%
import os
import json
from utils.vocabulary import *

import os
import json
from utils.vocabulary import *

data = "jigsaw"
root_dir = f"/scratch/yifwang/fairness_x_explainability/decoder_results_{data}"

models = ["llama_3b", "qwen3_4b"]
bias_types = ["race", "gender", "religion"]
debiasing_methods = ["zero_shot", "few_shot", "fairness_imagination", "fairness_instruction"]

if data == "civil":
    num_examples = {"race": 2000, "gender": 2000, "religion": 1000}
elif data == "jigsaw":
    num_examples = {"race": 400, "gender": 800, "religion": 200}

fairness_metrics = ["accuracy", "f1", "fpr", "fnr", "individual_fairness"]


methods = ["Attention", "Saliency", "DeepLift", "InputXGradient", "IntegratedGradients", "Occlusion", "KernelShap"]
#methods = ["Attention", "Saliency", "DeepLift", "InputXGradient", "Occlusion", "KernelShap"]
reliance_keys = ["raw", "max", "len", "norm"]

# %%
correlation_dict = {"model": [], "bias_type": [], "debiasing_method": [], "explanation_method": [], "correlation": [], "reliance_method": []}
for model in models:
    for bias_type in bias_types:
        for debiasing_method in debiasing_methods:
            for explanation_method in methods:
                file_path = os.path.join(root_dir, f"{model}_{data}_{bias_type}_test_{num_examples[bias_type]}", debiasing_method, "correlation", f"correlation_{explanation_method}_{bias_type}_test.json")
                if not os.path.exists(file_path):
                    print(f"File not found: {file_path}")
                    continue
                with open(file_path, "r") as f:
                    correlation_data = json.load(f)
                    if correlation_data is None or correlation_data == {}:
                        print(f"No data found in file: {file_path}")
                        continue
                for aggregation_method, value in correlation_data.items():
                    for reliance_method in reliance_keys:
                        correlation_dict["model"].append(model)
                        correlation_dict["bias_type"].append(bias_type)
                        correlation_dict["debiasing_method"].append(debiasing_method)
                        correlation_dict["explanation_method"].append(aggregation_method)
                        correlation_dict["correlation"].append(value['abs_average'][reliance_method])
                        correlation_dict["reliance_method"].append(reliance_method)
# Out:
# File not found: /scratch/yifwang/fairness_x_explainability/decoder_results_jigsaw/llama_3b_jigsaw_religion_test_200/few_shot/correlation/correlation_IntegratedGradients_religion_test.json
# File not found: /scratch/yifwang/fairness_x_explainability/decoder_results_jigsaw/qwen3_4b_jigsaw_religion_test_200/zero_shot/correlation/correlation_IntegratedGradients_religion_test.json
# No data found in file: /scratch/yifwang/fairness_x_explainability/decoder_results_jigsaw/qwen3_4b_jigsaw_religion_test_200/few_shot/correlation/correlation_IntegratedGradients_religion_test.json

# %%
# convert to a pandas DataFrame
import pandas as pd
correlation_df = pd.DataFrame(correlation_dict)
correlation_df
# Out:
#         model bias_type debiasing_method explanation_method  correlation  \
# 0     qwen_3b      race        zero_shot      raw_attention     0.099832
# 1     qwen_3b      race        zero_shot      raw_attention     0.082013
# 2     qwen_3b      race        zero_shot      raw_attention     0.136150
# 3     qwen_3b      race        zero_shot      raw_attention     0.090346
# 4     qwen_3b      race        zero_shot  attention_rollout     0.094813
# ..        ...       ...              ...                ...          ...
# 491  qwen3_4b  religion        zero_shot      Occlusion_abs     0.173336
# 492  qwen3_4b  religion        zero_shot         KernelShap     0.142212
# 493  qwen3_4b  religion        zero_shot         KernelShap     0.114401
# 494  qwen3_4b  religion        zero_shot         KernelShap     0.159080
# 495  qwen3_4b  religion        zero_shot         KernelShap     0.143908
#
#     reliance_method
# 0               raw
# 1               max
# 2               len
# 3              norm
# 4               raw
# ..              ...
# 491            norm
# 492             raw
# 493             max
# 494             len
# 495            norm
#
# [496 rows x 6 columns]

# %%
# average correlation for different debiasing methods
for debiasing_method in debiasing_methods:
    average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['debiasing_method'] == debiasing_method)].groupby('explanation_method')['correlation'].mean()
    print(f"\nAverage correlation for debiasing method '{debiasing_method}':")
    print(average_corr_df)
# Out:
# Average correlation for debiasing method 'zero_shot':
# explanation_method
# DeepLift_L2                 0.313186
# DeepLift_mean               0.140623
# InputXGradient_L2           0.315880
# InputXGradient_mean         0.186493
# IntegratedGradients_L2      0.174136
# IntegratedGradients_mean    0.083884
# KernelShap                  0.080674
# Occlusion                   0.322549
# Occlusion_abs               0.340336
# Saliency_L2                 0.318151
# Saliency_mean               0.159238
# attention_flow              0.074387
# attention_rollout           0.073606
# raw_attention               0.169940
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'few_shot':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for debiasing method 'fairness_imagination':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for debiasing method 'fairness_instruction':
# Series([], Name: correlation, dtype: float64)

# %%
# average correlation for different training types

for bias_type in bias_types:
    print(f"\nAverage correlation for bias type '{bias_type}':")
    average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['bias_type'] == bias_type)].groupby('explanation_method')['correlation'].mean()
    print(average_corr_df)
# Out:
# Average correlation for bias type 'race':
# explanation_method
# DeepLift_L2                 0.231612
# DeepLift_mean               0.140809
# InputXGradient_L2           0.239944
# InputXGradient_mean         0.204611
# IntegratedGradients_L2      0.152402
# IntegratedGradients_mean    0.069683
# KernelShap                  0.080430
# Occlusion                   0.246953
# Occlusion_abs               0.219718
# Saliency_L2                 0.239122
# Saliency_mean               0.133599
# attention_flow              0.058898
# attention_rollout           0.077325
# raw_attention               0.131889
# Name: correlation, dtype: float64
#
# Average correlation for bias type 'gender':
# explanation_method
# DeepLift_L2                 0.266448
# DeepLift_mean               0.088323
# InputXGradient_L2           0.266466
# InputXGradient_mean         0.115941
# IntegratedGradients_L2      0.160648
# IntegratedGradients_mean    0.066596
# KernelShap                  0.047511
# Occlusion                   0.315709
# Occlusion_abs               0.360756
# Saliency_L2                 0.269128
# Saliency_mean               0.077263
# attention_flow              0.023658
# attention_rollout           0.052237
# raw_attention               0.127315
# Name: correlation, dtype: float64
#
# Average correlation for bias type 'religion':
# explanation_method
# DeepLift_L2                 0.441500
# DeepLift_mean               0.192739
# InputXGradient_L2           0.441231
# InputXGradient_mean         0.238928
# IntegratedGradients_L2      0.226969
# IntegratedGradients_mean    0.131118
# KernelShap                  0.114082
# Occlusion                   0.404986
# Occlusion_abs               0.440533
# Saliency_L2                 0.446202
# Saliency_mean               0.266851
# attention_flow              0.140606
# attention_rollout           0.091258
# raw_attention               0.250616
# Name: correlation, dtype: float64

# %%
# average correlation of each explanation method for each debiasing method and training type
for bias_type in bias_types:
    for model in models:

        for debiasing_method in debiasing_methods:

            average_corr_df = correlation_df[(correlation_df['model'] == model) & (correlation_df['bias_type'] == bias_type) & (correlation_df['reliance_method'] == 'raw') & (correlation_df['debiasing_method'] == debiasing_method)].groupby('explanation_method')['correlation'].mean()
            print(f"\nAverage correlation for model '{model}', bias type '{bias_type}' debiasing method '{debiasing_method}'':")
            print(average_corr_df)
# Out:
# Average correlation for model 'qwen_3b', bias type 'race' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.151971
# DeepLift_mean               0.142815
# InputXGradient_L2           0.157426
# InputXGradient_mean         0.262467
# IntegratedGradients_L2      0.022751
# IntegratedGradients_mean    0.032969
# KernelShap                  0.129740
# Occlusion                   0.369940
# Occlusion_abs               0.217725
# Saliency_L2                 0.163181
# Saliency_mean               0.048002
# attention_flow              0.060826
# attention_rollout           0.094813
# raw_attention               0.099832
# Name: correlation, dtype: float64
#
# Average correlation for model 'qwen_3b', bias type 'race' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'race' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'race' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'race' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.209034
# DeepLift_mean               0.159286
# InputXGradient_L2           0.227972
# InputXGradient_mean         0.204183
# IntegratedGradients_L2      0.162941
# IntegratedGradients_mean    0.099009
# KernelShap                  0.063546
# Occlusion                   0.150111
# Occlusion_abs               0.205619
# Saliency_L2                 0.224976
# Saliency_mean               0.191221
# attention_flow              0.050470
# attention_rollout           0.063183
# raw_attention               0.103900
# Name: correlation, dtype: float64
#
# Average correlation for model 'llama_3b', bias type 'race' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'race' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'race' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'race' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.333829
# DeepLift_mean               0.120325
# InputXGradient_L2           0.334433
# InputXGradient_mean         0.147183
# IntegratedGradients_L2      0.271513
# IntegratedGradients_mean    0.077072
# KernelShap                  0.048005
# Occlusion                   0.220808
# Occlusion_abs               0.235808
# Saliency_L2                 0.329210
# Saliency_mean               0.161575
# attention_flow              0.065397
# attention_rollout           0.073978
# raw_attention               0.191934
# Name: correlation, dtype: float64
#
# Average correlation for model 'qwen3_4b', bias type 'race' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'race' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'race' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'gender' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.133104
# DeepLift_mean               0.107288
# InputXGradient_L2           0.134004
# InputXGradient_mean         0.134393
# IntegratedGradients_L2      0.074994
# IntegratedGradients_mean    0.074299
# KernelShap                  0.025292
# Occlusion                   0.282568
# Occlusion_abs               0.310198
# Saliency_L2                 0.137662
# Saliency_mean               0.112703
# attention_flow              0.021099
# attention_rollout           0.042650
# raw_attention               0.155732
# Name: correlation, dtype: float64
#
# Average correlation for model 'qwen_3b', bias type 'gender' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'gender' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'gender' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'gender' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.320351
# DeepLift_mean               0.050288
# InputXGradient_L2           0.314786
# InputXGradient_mean         0.132539
# IntegratedGradients_L2      0.206307
# IntegratedGradients_mean    0.074028
# KernelShap                  0.060242
# Occlusion                   0.301626
# Occlusion_abs               0.421034
# Saliency_L2                 0.321646
# Saliency_mean               0.057563
# attention_flow              0.038347
# attention_rollout           0.070309
# raw_attention               0.113718
# Name: correlation, dtype: float64
#
# Average correlation for model 'llama_3b', bias type 'gender' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'gender' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'gender' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'gender' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.345888
# DeepLift_mean               0.107393
# InputXGradient_L2           0.350608
# InputXGradient_mean         0.080890
# IntegratedGradients_L2      0.200643
# IntegratedGradients_mean    0.051461
# KernelShap                  0.056998
# Occlusion                   0.362932
# Occlusion_abs               0.351037
# Saliency_L2                 0.348078
# Saliency_mean               0.061524
# attention_flow              0.011526
# attention_rollout           0.043751
# raw_attention               0.112495
# Name: correlation, dtype: float64
#
# Average correlation for model 'qwen3_4b', bias type 'gender' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'gender' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'gender' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'religion' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.308900
# DeepLift_mean               0.203372
# InputXGradient_L2           0.308360
# InputXGradient_mean         0.264327
# IntegratedGradients_L2      0.099716
# IntegratedGradients_mean    0.113095
# KernelShap                  0.110111
# Occlusion                   0.426836
# Occlusion_abs               0.423892
# Saliency_L2                 0.304074
# Saliency_mean               0.172334
# attention_flow              0.107963
# attention_rollout           0.119743
# raw_attention               0.222189
# Name: correlation, dtype: float64
#
# Average correlation for model 'qwen_3b', bias type 'religion' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'religion' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen_3b', bias type 'religion' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'religion' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2                 0.433527
# DeepLift_mean               0.170056
# InputXGradient_L2           0.434901
# InputXGradient_mean         0.185832
# IntegratedGradients_L2      0.354222
# IntegratedGradients_mean    0.149141
# KernelShap                  0.089922
# Occlusion                   0.405135
# Occlusion_abs               0.558367
# Saliency_L2                 0.449244
# Saliency_mean               0.315378
# attention_flow              0.104812
# attention_rollout           0.086513
# raw_attention               0.259241
# Name: correlation, dtype: float64
#
# Average correlation for model 'llama_3b', bias type 'religion' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'religion' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'llama_3b', bias type 'religion' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'religion' debiasing method 'zero_shot'':
# explanation_method
# DeepLift_L2            0.582073
# DeepLift_mean          0.204789
# InputXGradient_L2      0.580434
# InputXGradient_mean    0.266625
# KernelShap             0.142212
# Occlusion              0.382985
# Occlusion_abs          0.339340
# Saliency_L2            0.585288
# Saliency_mean          0.312840
# attention_flow         0.209042
# attention_rollout      0.067517
# raw_attention          0.270418
# Name: correlation, dtype: float64
#
# Average correlation for model 'qwen3_4b', bias type 'religion' debiasing method 'few_shot'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'religion' debiasing method 'fairness_imagination'':
# Series([], Name: correlation, dtype: float64)
#
# Average correlation for model 'qwen3_4b', bias type 'religion' debiasing method 'fairness_instruction'':
# Series([], Name: correlation, dtype: float64)
