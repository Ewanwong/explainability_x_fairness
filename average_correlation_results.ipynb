# %%
import os
import json
from utils.vocabulary import *

import os
import json
from utils.vocabulary import *

data = "jigsaw"
root_dir = f"/scratch/yifwang/new_fairness_x_explainability/encoder_results_{data}"
models = ["bert", "roberta", "distilbert"]
bias_types = ["race", "gender", "religion"]
debiasing_methods = ["no_debiasing", "group_balance", "group_class_balance", "cda", "dropout", "attention_entropy", "causal_debias"]

training_types = ["all axes", "one axis"]
if data == "civil":
    num_examples = {"race": 2000, "gender": 2000, "religion": 1000}
elif data == "jigsaw":
    num_examples = {"race": 400, "gender": 800, "religion": 200}
fairness_metrics = ["accuracy", "f1", "fpr", "fnr", "individual_fairness"]


methods = ["Attention", "Saliency", "DeepLift", "InputXGradient", "IntegratedGradients", "Occlusion", "KernelShap"]
reliance_keys = ["raw", "max", "len", "norm"]

# %%
correlation_dict = {"model": [], "bias_type": [], "debiasing_method": [], "training_data": [], "explanation_method": [], "correlation": [], "reliance_method": []}
for model in models:
    for bias_type in bias_types:
        for training_type in training_types:
            data_token = "all" if training_type == "all axes" else bias_type
            for debiasing_method in debiasing_methods:
                for explanation_method in methods:
                    file_path = os.path.join(root_dir, f"{model}_{data}_{data_token}_{bias_type}_test_{num_examples[bias_type]}", debiasing_method, "correlation", f"correlation_{explanation_method}_{bias_type}_test.json")
                    if not os.path.exists(file_path):
                        print(f"File not found: {file_path}")
                        continue
                    with open(file_path, "r") as f:
                        correlation_data = json.load(f)
                    for aggregation_method, value in correlation_data.items():
                        for reliance_method in reliance_keys:
                            correlation_dict["model"].append(model)
                            correlation_dict["bias_type"].append(bias_type)
                            correlation_dict["debiasing_method"].append(debiasing_method)
                            correlation_dict["training_data"].append(training_type)
                            correlation_dict["explanation_method"].append(aggregation_method)
                            correlation_dict["correlation"].append(value['abs_average'][reliance_method])
                            correlation_dict["reliance_method"].append(reliance_method)

# %%
# convert to a pandas DataFrame
import pandas as pd
correlation_df = pd.DataFrame(correlation_dict)
correlation_df
# Out:
#            model bias_type debiasing_method training_data explanation_method  \
# 0           bert      race     no_debiasing      all axes      raw_attention
# 1           bert      race     no_debiasing      all axes      raw_attention
# 2           bert      race     no_debiasing      all axes      raw_attention
# 3           bert      race     no_debiasing      all axes      raw_attention
# 4           bert      race     no_debiasing      all axes  attention_rollout
# ...          ...       ...              ...           ...                ...
# 7051  distilbert  religion    causal_debias      one axis      Occlusion_abs
# 7052  distilbert  religion    causal_debias      one axis       ShapleyValue
# 7053  distilbert  religion    causal_debias      one axis       ShapleyValue
# 7054  distilbert  religion    causal_debias      one axis       ShapleyValue
# 7055  distilbert  religion    causal_debias      one axis       ShapleyValue
#
#       correlation reliance_method
# 0        0.619244             raw
# 1        0.579729             max
# 2        0.598964             len
# 3        0.572680            norm
# 4        0.578462             raw
# ...           ...             ...
# 7051     0.403299            norm
# 7052     0.124311             raw
# 7053     0.111509             max
# 7054     0.194168             len
# 7055     0.161390            norm
#
# [7056 rows x 7 columns]

# %%
# show the average correlation for each explanation method with raw reliance method
average_corr_df = correlation_df[correlation_df['reliance_method'] == 'raw'].groupby('explanation_method')['correlation'].mean()
print(average_corr_df)
# Out:
# explanation_method
# DeepLift_L2                 0.438122
# DeepLift_mean               0.251806
# InputXGradient_L2           0.432942
# InputXGradient_mean         0.296284
# IntegratedGradients_L2      0.380105
# IntegratedGradients_mean    0.298514
# Occlusion                   0.480676
# Occlusion_abs               0.501809
# Saliency_L2                 0.433678
# Saliency_mean               0.300379
# ShapleyValue                0.154751
# attention_flow              0.257263
# attention_rollout           0.313854
# raw_attention               0.318524
# Name: correlation, dtype: float64

# %%
# show correlation for each bias type and debiasing method
for bias_type in bias_types:
    average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['bias_type'] == bias_type)].groupby('explanation_method')['correlation'].mean()
    print(f"\nAverage correlation for bias type '{bias_type}':")
    print(average_corr_df)
# Out:
# Average correlation for bias type 'race':
# explanation_method
# DeepLift_L2                 0.544246
# DeepLift_mean               0.239439
# InputXGradient_L2           0.536281
# InputXGradient_mean         0.323131
# IntegratedGradients_L2      0.500451
# IntegratedGradients_mean    0.332616
# Occlusion                   0.571854
# Occlusion_abs               0.617462
# Saliency_L2                 0.536107
# Saliency_mean               0.333400
# ShapleyValue                0.158977
# attention_flow              0.358707
# attention_rollout           0.477709
# raw_attention               0.492419
# Name: correlation, dtype: float64
#
# Average correlation for bias type 'gender':
# explanation_method
# DeepLift_L2                 0.308288
# DeepLift_mean               0.195723
# InputXGradient_L2           0.310008
# InputXGradient_mean         0.224252
# IntegratedGradients_L2      0.245095
# IntegratedGradients_mean    0.234074
# Occlusion                   0.355813
# Occlusion_abs               0.356033
# Saliency_L2                 0.310056
# Saliency_mean               0.241137
# ShapleyValue                0.127126
# attention_flow              0.137174
# attention_rollout           0.155334
# raw_attention               0.157218
# Name: correlation, dtype: float64
#
# Average correlation for bias type 'religion':
# explanation_method
# DeepLift_L2                 0.461831
# DeepLift_mean               0.320255
# InputXGradient_L2           0.452536
# InputXGradient_mean         0.341470
# IntegratedGradients_L2      0.394768
# IntegratedGradients_mean    0.328852
# Occlusion                   0.514360
# Occlusion_abs               0.531931
# Saliency_L2                 0.454871
# Saliency_mean               0.326600
# ShapleyValue                0.178152
# attention_flow              0.275907
# attention_rollout           0.308519
# raw_attention               0.305933
# Name: correlation, dtype: float64

# %%
# average correlation for different debiasing methods
for debiasing_method in debiasing_methods:
    average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['debiasing_method'] == debiasing_method)].groupby('explanation_method')['correlation'].mean()
    print(f"\nAverage correlation for debiasing method '{debiasing_method}':")
    print(average_corr_df)
# Out:
# Average correlation for debiasing method 'no_debiasing':
# explanation_method
# DeepLift_L2                 0.456196
# DeepLift_mean               0.269720
# InputXGradient_L2           0.448412
# InputXGradient_mean         0.334086
# IntegratedGradients_L2      0.397259
# IntegratedGradients_mean    0.309048
# Occlusion                   0.546162
# Occlusion_abs               0.539814
# Saliency_L2                 0.447181
# Saliency_mean               0.301602
# ShapleyValue                0.156088
# attention_flow              0.255589
# attention_rollout           0.328570
# raw_attention               0.328281
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_balance':
# explanation_method
# DeepLift_L2                 0.457427
# DeepLift_mean               0.269614
# InputXGradient_L2           0.453581
# InputXGradient_mean         0.247981
# IntegratedGradients_L2      0.401997
# IntegratedGradients_mean    0.329092
# Occlusion                   0.471468
# Occlusion_abs               0.531458
# Saliency_L2                 0.455411
# Saliency_mean               0.288256
# ShapleyValue                0.180240
# attention_flow              0.272216
# attention_rollout           0.344100
# raw_attention               0.357753
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_class_balance':
# explanation_method
# DeepLift_L2                 0.450636
# DeepLift_mean               0.268366
# InputXGradient_L2           0.450139
# InputXGradient_mean         0.345001
# IntegratedGradients_L2      0.402398
# IntegratedGradients_mean    0.328928
# Occlusion                   0.472526
# Occlusion_abs               0.480532
# Saliency_L2                 0.449548
# Saliency_mean               0.326070
# ShapleyValue                0.136466
# attention_flow              0.296496
# attention_rollout           0.365138
# raw_attention               0.366133
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'cda':
# explanation_method
# DeepLift_L2                 0.338591
# DeepLift_mean               0.242144
# InputXGradient_L2           0.340944
# InputXGradient_mean         0.287918
# IntegratedGradients_L2      0.269875
# IntegratedGradients_mean    0.232698
# Occlusion                   0.385215
# Occlusion_abs               0.379976
# Saliency_L2                 0.341880
# Saliency_mean               0.289091
# ShapleyValue                0.127013
# attention_flow              0.168390
# attention_rollout           0.201554
# raw_attention               0.189349
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'dropout':
# explanation_method
# DeepLift_L2                 0.458290
# DeepLift_mean               0.258516
# InputXGradient_L2           0.446133
# InputXGradient_mean         0.306743
# IntegratedGradients_L2      0.386192
# IntegratedGradients_mean    0.283716
# Occlusion                   0.499308
# Occlusion_abs               0.514953
# Saliency_L2                 0.447297
# Saliency_mean               0.331075
# ShapleyValue                0.161129
# attention_flow              0.273155
# attention_rollout           0.332345
# raw_attention               0.336738
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'attention_entropy':
# explanation_method
# DeepLift_L2                 0.416167
# DeepLift_mean               0.213440
# InputXGradient_L2           0.407556
# InputXGradient_mean         0.275302
# IntegratedGradients_L2      0.372749
# IntegratedGradients_mean    0.280557
# Occlusion                   0.483692
# Occlusion_abs               0.496396
# Saliency_L2                 0.407301
# Saliency_mean               0.292127
# ShapleyValue                0.159195
# attention_flow              0.261748
# attention_rollout           0.303880
# raw_attention               0.312895
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'causal_debias':
# explanation_method
# DeepLift_L2                 0.489546
# DeepLift_mean               0.240842
# InputXGradient_L2           0.483828
# InputXGradient_mean         0.276960
# IntegratedGradients_L2      0.430263
# IntegratedGradients_mean    0.325557
# Occlusion                   0.506358
# Occlusion_abs               0.569534
# Saliency_L2                 0.487126
# Saliency_mean               0.274435
# ShapleyValue                0.163129
# attention_flow              0.273245
# attention_rollout           0.321392
# raw_attention               0.338515
# Name: correlation, dtype: float64

# %%
# average correlation for different debiasing methods
for debiasing_method in debiasing_methods:
    average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['debiasing_method'] == debiasing_method)].groupby(['explanation_method', "bias_type"])['correlation'].mean()
    print(f"\nAverage correlation for debiasing method '{debiasing_method}':")
    print(average_corr_df)
# Out:
# Average correlation for debiasing method 'no_debiasing':
# explanation_method        bias_type
# DeepLift_L2               gender       0.267080
#                           race         0.613960
#                           religion     0.487547
# DeepLift_mean             gender       0.211517
#                           race         0.250081
#                           religion     0.347563
# InputXGradient_L2         gender       0.274912
#                           race         0.598037
#                           religion     0.472287
# InputXGradient_mean       gender       0.225975
#                           race         0.399152
#                           religion     0.377131
# IntegratedGradients_L2    gender       0.224063
#                           race         0.563290
#                           religion     0.404424
# IntegratedGradients_mean  gender       0.248755
#                           race         0.357760
#                           religion     0.320628
# Occlusion                 gender       0.400597
#                           race         0.646113
#                           religion     0.591777
# Occlusion_abs             gender       0.343780
#                           race         0.683761
#                           religion     0.591902
# Saliency_L2               gender       0.272125
#                           race         0.596437
#                           religion     0.472983
# Saliency_mean             gender       0.241221
#                           race         0.349218
#                           religion     0.314366
# ShapleyValue              gender       0.118421
#                           race         0.171320
#                           religion     0.178524
# attention_flow            gender       0.113367
#                           race         0.405568
#                           religion     0.247834
# attention_rollout         gender       0.135080
#                           race         0.539496
#                           religion     0.311133
# raw_attention             gender       0.129874
#                           race         0.552151
#                           religion     0.302819
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_balance':
# explanation_method        bias_type
# DeepLift_L2               gender       0.311806
#                           race         0.630870
#                           religion     0.429605
# DeepLift_mean             gender       0.230290
#                           race         0.273465
#                           religion     0.305087
# InputXGradient_L2         gender       0.315254
#                           race         0.629178
#                           religion     0.416311
# InputXGradient_mean       gender       0.197462
#                           race         0.286147
#                           religion     0.260333
# IntegratedGradients_L2    gender       0.262184
#                           race         0.603106
#                           religion     0.340701
# IntegratedGradients_mean  gender       0.281974
#                           race         0.412122
#                           religion     0.293178
# Occlusion                 gender       0.336412
#                           race         0.662532
#                           religion     0.415459
# Occlusion_abs             gender       0.351798
#                           race         0.724256
#                           religion     0.518319
# Saliency_L2               gender       0.318274
#                           race         0.628758
#                           religion     0.419201
# Saliency_mean             gender       0.196360
#                           race         0.378699
#                           religion     0.289711
# ShapleyValue              gender       0.165351
#                           race         0.187588
#                           religion     0.187779
# attention_flow            gender       0.185434
#                           race         0.395203
#                           religion     0.236011
# attention_rollout         gender       0.179419
#                           race         0.569244
#                           religion     0.283636
# raw_attention             gender       0.175852
#                           race         0.606405
#                           religion     0.291001
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_class_balance':
# explanation_method        bias_type
# DeepLift_L2               gender       0.389613
#                           race         0.521509
#                           religion     0.440785
# DeepLift_mean             gender       0.212184
#                           race         0.235362
#                           religion     0.357551
# InputXGradient_L2         gender       0.386972
#                           race         0.512110
#                           religion     0.451334
# InputXGradient_mean       gender       0.278449
#                           race         0.345375
#                           religion     0.411178
# IntegratedGradients_L2    gender       0.303637
#                           race         0.494996
#                           religion     0.408560
# IntegratedGradients_mean  gender       0.260608
#                           race         0.321426
#                           religion     0.404749
# Occlusion                 gender       0.372241
#                           race         0.534031
#                           religion     0.511306
# Occlusion_abs             gender       0.377308
#                           race         0.576641
#                           religion     0.487646
# Saliency_L2               gender       0.387136
#                           race         0.509754
#                           religion     0.451755
# Saliency_mean             gender       0.336108
#                           race         0.328824
#                           religion     0.313278
# ShapleyValue              gender       0.091186
#                           race         0.152151
#                           religion     0.166062
# attention_flow            gender       0.171473
#                           race         0.396315
#                           religion     0.321699
# attention_rollout         gender       0.223115
#                           race         0.516861
#                           religion     0.355440
# raw_attention             gender       0.229643
#                           race         0.528621
#                           religion     0.340136
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'cda':
# explanation_method        bias_type
# DeepLift_L2               gender       0.261124
#                           race         0.352474
#                           religion     0.402174
# DeepLift_mean             gender       0.209788
#                           race         0.214362
#                           religion     0.302281
# InputXGradient_L2         gender       0.258799
#                           race         0.358911
#                           religion     0.405122
# InputXGradient_mean       gender       0.244525
#                           race         0.286372
#                           religion     0.332855
# IntegratedGradients_L2    gender       0.185745
#                           race         0.277116
#                           religion     0.346764
# IntegratedGradients_mean  gender       0.146492
#                           race         0.227176
#                           religion     0.324426
# Occlusion                 gender       0.286910
#                           race         0.358675
#                           religion     0.510061
# Occlusion_abs             gender       0.300928
#                           race         0.371659
#                           religion     0.467341
# Saliency_L2               gender       0.262386
#                           race         0.359794
#                           religion     0.403462
# Saliency_mean             gender       0.198594
#                           race         0.301628
#                           religion     0.367053
# ShapleyValue              gender       0.113062
#                           race         0.130387
#                           religion     0.137590
# attention_flow            gender       0.090548
#                           race         0.175596
#                           religion     0.239024
# attention_rollout         gender       0.106615
#                           race         0.205910
#                           religion     0.292135
# raw_attention             gender       0.087193
#                           race         0.201065
#                           religion     0.279788
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'dropout':
# explanation_method        bias_type
# DeepLift_L2               gender       0.303940
#                           race         0.557717
#                           religion     0.513213
# DeepLift_mean             gender       0.161243
#                           race         0.274170
#                           religion     0.340133
# InputXGradient_L2         gender       0.306667
#                           race         0.543427
#                           religion     0.488305
# InputXGradient_mean       gender       0.216357
#                           race         0.322564
#                           religion     0.381307
# IntegratedGradients_L2    gender       0.212724
#                           race         0.505138
#                           religion     0.440713
# IntegratedGradients_mean  gender       0.220094
#                           race         0.321740
#                           religion     0.309315
# Occlusion                 gender       0.364892
#                           race         0.570271
#                           religion     0.562760
# Occlusion_abs             gender       0.367486
#                           race         0.603398
#                           religion     0.573974
# Saliency_L2               gender       0.308522
#                           race         0.541810
#                           religion     0.491560
# Saliency_mean             gender       0.282854
#                           race         0.358446
#                           religion     0.351924
# ShapleyValue              gender       0.118416
#                           race         0.158450
#                           religion     0.206522
# attention_flow            gender       0.129952
#                           race         0.404617
#                           religion     0.284897
# attention_rollout         gender       0.162587
#                           race         0.512477
#                           religion     0.321971
# raw_attention             gender       0.153764
#                           race         0.521197
#                           religion     0.335253
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'attention_entropy':
# explanation_method        bias_type
# DeepLift_L2               gender       0.256148
#                           race         0.534061
#                           religion     0.458291
# DeepLift_mean             gender       0.158358
#                           race         0.199147
#                           religion     0.282816
# InputXGradient_L2         gender       0.261644
#                           race         0.520395
#                           religion     0.440628
# InputXGradient_mean       gender       0.183545
#                           race         0.324701
#                           religion     0.317659
# IntegratedGradients_L2    gender       0.193409
#                           race         0.516379
#                           religion     0.408460
# IntegratedGradients_mean  gender       0.229112
#                           race         0.320817
#                           religion     0.291743
# Occlusion                 gender       0.335158
#                           race         0.618446
#                           religion     0.497473
# Occlusion_abs             gender       0.309866
#                           race         0.655685
#                           religion     0.523638
# Saliency_L2               gender       0.259619
#                           race         0.516940
#                           religion     0.445344
# Saliency_mean             gender       0.206319
#                           race         0.317829
#                           religion     0.352233
# ShapleyValue              gender       0.163575
#                           race         0.159343
#                           religion     0.154666
# attention_flow            gender       0.099151
#                           race         0.373984
#                           religion     0.312110
# attention_rollout         gender       0.084755
#                           race         0.534896
#                           religion     0.291989
# raw_attention             gender       0.104750
#                           race         0.554405
#                           religion     0.279531
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'causal_debias':
# explanation_method        bias_type
# DeepLift_L2               gender       0.368302
#                           race         0.599132
#                           religion     0.501204
# DeepLift_mean             gender       0.186682
#                           race         0.229488
#                           religion     0.306356
# InputXGradient_L2         gender       0.365808
#                           race         0.591909
#                           religion     0.493766
# InputXGradient_mean       gender       0.223448
#                           race         0.297606
#                           religion     0.309827
# IntegratedGradients_L2    gender       0.333904
#                           race         0.543129
#                           religion     0.413755
# IntegratedGradients_mean  gender       0.251481
#                           race         0.367268
#                           religion     0.357922
# Occlusion                 gender       0.394483
#                           race         0.612908
#                           religion     0.511682
# Occlusion_abs             gender       0.441069
#                           race         0.706837
#                           religion     0.560695
# Saliency_L2               gender       0.362331
#                           race         0.599258
#                           religion     0.499790
# Saliency_mean             gender       0.226507
#                           race         0.299159
#                           religion     0.297639
# ShapleyValue              gender       0.119869
#                           race         0.153602
#                           religion     0.215917
# attention_flow            gender       0.170291
#                           race         0.359669
#                           religion     0.289776
# attention_rollout         gender       0.195768
#                           race         0.465077
#                           religion     0.303331
# raw_attention             gender       0.219454
#                           race         0.483088
#                           religion     0.313003
# Name: correlation, dtype: float64

# %%
# average correlation for different training types
for training_type in training_types:
    for bias_type in bias_types:
        print(f"\nAverage correlation for training type '{training_type}' and bias type '{bias_type}':")
        average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['training_data'] == training_type) & (correlation_df['bias_type'] == bias_type)].groupby('explanation_method')['correlation'].mean()
        print(average_corr_df)
# Out:
# Average correlation for training type 'all axes' and bias type 'race':
# explanation_method
# DeepLift_L2                 0.515741
# DeepLift_mean               0.199269
# InputXGradient_L2           0.509814
# InputXGradient_mean         0.314981
# IntegratedGradients_L2      0.464547
# IntegratedGradients_mean    0.348157
# Occlusion                   0.599968
# Occlusion_abs               0.605123
# Saliency_L2                 0.511414
# Saliency_mean               0.353758
# ShapleyValue                0.161724
# attention_flow              0.322342
# attention_rollout           0.433067
# raw_attention               0.454428
# Name: correlation, dtype: float64
#
# Average correlation for training type 'all axes' and bias type 'gender':
# explanation_method
# DeepLift_L2                 0.293601
# DeepLift_mean               0.192335
# InputXGradient_L2           0.291429
# InputXGradient_mean         0.197504
# IntegratedGradients_L2      0.236013
# IntegratedGradients_mean    0.224258
# Occlusion                   0.343890
# Occlusion_abs               0.344300
# Saliency_L2                 0.289046
# Saliency_mean               0.221219
# ShapleyValue                0.103340
# attention_flow              0.126357
# attention_rollout           0.137908
# raw_attention               0.136725
# Name: correlation, dtype: float64
#
# Average correlation for training type 'all axes' and bias type 'religion':
# explanation_method
# DeepLift_L2                 0.447003
# DeepLift_mean               0.308015
# InputXGradient_L2           0.441147
# InputXGradient_mean         0.342730
# IntegratedGradients_L2      0.386678
# IntegratedGradients_mean    0.344073
# Occlusion                   0.518099
# Occlusion_abs               0.543035
# Saliency_L2                 0.444099
# Saliency_mean               0.331257
# ShapleyValue                0.176003
# attention_flow              0.266785
# attention_rollout           0.334966
# raw_attention               0.326920
# Name: correlation, dtype: float64
#
# Average correlation for training type 'one axis' and bias type 'race':
# explanation_method
# DeepLift_L2                 0.572751
# DeepLift_mean               0.279610
# InputXGradient_L2           0.562748
# InputXGradient_mean         0.331281
# IntegratedGradients_L2      0.536354
# IntegratedGradients_mean    0.317074
# Occlusion                   0.543739
# Occlusion_abs               0.629802
# Saliency_L2                 0.560801
# Saliency_mean               0.313043
# ShapleyValue                0.156230
# attention_flow              0.395073
# attention_rollout           0.522350
# raw_attention               0.530410
# Name: correlation, dtype: float64
#
# Average correlation for training type 'one axis' and bias type 'gender':
# explanation_method
# DeepLift_L2                 0.322975
# DeepLift_mean               0.199111
# InputXGradient_L2           0.328587
# InputXGradient_mean         0.250999
# IntegratedGradients_L2      0.254177
# IntegratedGradients_mean    0.243889
# Occlusion                   0.367737
# Occlusion_abs               0.367767
# Saliency_L2                 0.331066
# Saliency_mean               0.261056
# ShapleyValue                0.150912
# attention_flow              0.147990
# attention_rollout           0.172760
# raw_attention               0.177712
# Name: correlation, dtype: float64
#
# Average correlation for training type 'one axis' and bias type 'religion':
# explanation_method
# DeepLift_L2                 0.476659
# DeepLift_mean               0.332495
# InputXGradient_L2           0.463925
# InputXGradient_mean         0.340211
# IntegratedGradients_L2      0.402858
# IntegratedGradients_mean    0.313631
# Occlusion                   0.510620
# Occlusion_abs               0.520827
# Saliency_L2                 0.465642
# Saliency_mean               0.321944
# ShapleyValue                0.180300
# attention_flow              0.285030
# attention_rollout           0.282072
# raw_attention               0.284946
# Name: correlation, dtype: float64

# %%
for explanation_methods in correlation_df['explanation_method'].unique():
    average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['explanation_method'] == explanation_methods)].groupby(['debiasing_method', 'training_data'])['correlation'].mean()
    print(f"\nAverage correlation for explanation method '{explanation_methods}':")
    print(average_corr_df)
# Out:
# Average correlation for explanation method 'raw_attention':
# debiasing_method     training_data
# attention_entropy    all axes         0.283534
#                      one axis         0.342257
# causal_debias        all axes         0.268775
#                      one axis         0.408254
# cda                  all axes         0.220894
#                      one axis         0.157803
# dropout              all axes         0.302334
#                      one axis         0.371142
# group_balance        all axes         0.337411
#                      one axis         0.378095
# group_class_balance  all axes         0.387342
#                      one axis         0.344925
# no_debiasing         all axes         0.341881
#                      one axis         0.314682
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'attention_rollout':
# debiasing_method     training_data
# attention_entropy    all axes         0.269448
#                      one axis         0.338312
# causal_debias        all axes         0.256585
#                      one axis         0.386198
# cda                  all axes         0.243618
#                      one axis         0.159489
# dropout              all axes         0.298065
#                      one axis         0.366625
# group_balance        all axes         0.332236
#                      one axis         0.355963
# group_class_balance  all axes         0.377589
#                      one axis         0.352688
# no_debiasing         all axes         0.336322
#                      one axis         0.320817
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'attention_flow':
# debiasing_method     training_data
# attention_entropy    all axes         0.221848
#                      one axis         0.301649
# causal_debias        all axes         0.210796
#                      one axis         0.335695
# cda                  all axes         0.179968
#                      one axis         0.156811
# dropout              all axes         0.228147
#                      one axis         0.318164
# group_balance        all axes         0.271031
#                      one axis         0.273402
# group_class_balance  all axes         0.288598
#                      one axis         0.304393
# no_debiasing         all axes         0.269076
#                      one axis         0.242103
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'Saliency_L2':
# debiasing_method     training_data
# attention_entropy    all axes         0.371278
#                      one axis         0.443325
# causal_debias        all axes         0.446751
#                      one axis         0.527502
# cda                  all axes         0.363982
#                      one axis         0.319779
# dropout              all axes         0.410951
#                      one axis         0.483644
# group_balance        all axes         0.455947
#                      one axis         0.454874
# group_class_balance  all axes         0.432987
#                      one axis         0.466109
# no_debiasing         all axes         0.422076
#                      one axis         0.472287
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'Saliency_mean':
# debiasing_method     training_data
# attention_entropy    all axes         0.291496
#                      one axis         0.292758
# causal_debias        all axes         0.296614
#                      one axis         0.252256
# cda                  all axes         0.284304
#                      one axis         0.293879
# dropout              all axes         0.317481
#                      one axis         0.344668
# group_balance        all axes         0.304219
#                      one axis         0.272294
# group_class_balance  all axes         0.327528
#                      one axis         0.324611
# no_debiasing         all axes         0.292903
#                      one axis         0.310301
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'DeepLift_L2':
# debiasing_method     training_data
# attention_entropy    all axes         0.375151
#                      one axis         0.457182
# causal_debias        all axes         0.455088
#                      one axis         0.524004
# cda                  all axes         0.364569
#                      one axis         0.312613
# dropout              all axes         0.416757
#                      one axis         0.499823
# group_balance        all axes         0.457120
#                      one axis         0.457734
# group_class_balance  all axes         0.430882
#                      one axis         0.470389
# no_debiasing         all axes         0.431904
#                      one axis         0.480487
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'DeepLift_mean':
# debiasing_method     training_data
# attention_entropy    all axes         0.187031
#                      one axis         0.239850
# causal_debias        all axes         0.213291
#                      one axis         0.268394
# cda                  all axes         0.263060
#                      one axis         0.221227
# dropout              all axes         0.255181
#                      one axis         0.261850
# group_balance        all axes         0.262067
#                      one axis         0.277161
# group_class_balance  all axes         0.234941
#                      one axis         0.301791
# no_debiasing         all axes         0.216874
#                      one axis         0.322566
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'InputXGradient_L2':
# debiasing_method     training_data
# attention_entropy    all axes         0.370284
#                      one axis         0.444827
# causal_debias        all axes         0.444268
#                      one axis         0.523387
# cda                  all axes         0.363217
#                      one axis         0.318671
# dropout              all axes         0.408414
#                      one axis         0.483851
# group_balance        all axes         0.455696
#                      one axis         0.451466
# group_class_balance  all axes         0.434452
#                      one axis         0.465825
# no_debiasing         all axes         0.422578
#                      one axis         0.474246
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'InputXGradient_mean':
# debiasing_method     training_data
# attention_entropy    all axes         0.268409
#                      one axis         0.282194
# causal_debias        all axes         0.264537
#                      one axis         0.289384
# cda                  all axes         0.311530
#                      one axis         0.264305
# dropout              all axes         0.282707
#                      one axis         0.330779
# group_balance        all axes         0.250785
#                      one axis         0.245177
# group_class_balance  all axes         0.321079
#                      one axis         0.368923
# no_debiasing         all axes         0.296455
#                      one axis         0.371716
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'IntegratedGradients_L2':
# debiasing_method     training_data
# attention_entropy    all axes         0.335004
#                      one axis         0.410495
# causal_debias        all axes         0.398200
#                      one axis         0.462325
# cda                  all axes         0.277603
#                      one axis         0.262147
# dropout              all axes         0.343098
#                      one axis         0.429285
# group_balance        all axes         0.387659
#                      one axis         0.416335
# group_class_balance  all axes         0.400168
#                      one axis         0.404627
# no_debiasing         all axes         0.395159
#                      one axis         0.399360
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'IntegratedGradients_mean':
# debiasing_method     training_data
# attention_entropy    all axes         0.267615
#                      one axis         0.293500
# causal_debias        all axes         0.329340
#                      one axis         0.321774
# cda                  all axes         0.265075
#                      one axis         0.200321
# dropout              all axes         0.289870
#                      one axis         0.277562
# group_balance        all axes         0.326542
#                      one axis         0.331641
# group_class_balance  all axes         0.340933
#                      one axis         0.316922
# no_debiasing         all axes         0.319097
#                      one axis         0.298998
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'Occlusion':
# debiasing_method     training_data
# attention_entropy    all axes         0.506221
#                      one axis         0.461163
# causal_debias        all axes         0.520843
#                      one axis         0.491872
# cda                  all axes         0.385747
#                      one axis         0.384684
# dropout              all axes         0.481705
#                      one axis         0.516911
# group_balance        all axes         0.498807
#                      one axis         0.444128
# group_class_balance  all axes         0.489697
#                      one axis         0.455356
# no_debiasing         all axes         0.528216
#                      one axis         0.564109
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'Occlusion_abs':
# debiasing_method     training_data
# attention_entropy    all axes         0.500648
#                      one axis         0.492144
# causal_debias        all axes         0.543946
#                      one axis         0.595122
# cda                  all axes         0.405717
#                      one axis         0.354235
# dropout              all axes         0.480410
#                      one axis         0.549495
# group_balance        all axes         0.532635
#                      one axis         0.530281
# group_class_balance  all axes         0.492224
#                      one axis         0.468839
# no_debiasing         all axes         0.526822
#                      one axis         0.552807
# Name: correlation, dtype: float64
#
# Average correlation for explanation method 'ShapleyValue':
# debiasing_method     training_data
# attention_entropy    all axes         0.138154
#                      one axis         0.180236
# causal_debias        all axes         0.171559
#                      one axis         0.154700
# cda                  all axes         0.127681
#                      one axis         0.126345
# dropout              all axes         0.140884
#                      one axis         0.181374
# group_balance        all axes         0.170739
#                      one axis         0.189741
# group_class_balance  all axes         0.141300
#                      one axis         0.131632
# no_debiasing         all axes         0.138839
#                      one axis         0.173337
# Name: correlation, dtype: float64

# %%
# average correlation of each explanation method for each debiasing method and training type
for debiasing_method in debiasing_methods:
    for training_type in training_types:
        average_corr_df = correlation_df[(correlation_df['reliance_method'] == 'raw') & (correlation_df['debiasing_method'] == debiasing_method) & (correlation_df['training_data'] == training_type)].groupby('explanation_method')['correlation'].mean()
        print(f"\nAverage correlation for debiasing method '{debiasing_method}' and training type '{training_type}':")
        print(average_corr_df)
# Out:
# Average correlation for debiasing method 'no_debiasing' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.431904
# DeepLift_mean               0.216874
# InputXGradient_L2           0.422578
# InputXGradient_mean         0.296455
# IntegratedGradients_L2      0.395159
# IntegratedGradients_mean    0.319097
# Occlusion                   0.528216
# Occlusion_abs               0.526822
# Saliency_L2                 0.422076
# Saliency_mean               0.292903
# ShapleyValue                0.138839
# attention_flow              0.269076
# attention_rollout           0.336322
# raw_attention               0.341881
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'no_debiasing' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.480487
# DeepLift_mean               0.322566
# InputXGradient_L2           0.474246
# InputXGradient_mean         0.371716
# IntegratedGradients_L2      0.399360
# IntegratedGradients_mean    0.298998
# Occlusion                   0.564109
# Occlusion_abs               0.552807
# Saliency_L2                 0.472287
# Saliency_mean               0.310301
# ShapleyValue                0.173337
# attention_flow              0.242103
# attention_rollout           0.320817
# raw_attention               0.314682
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_balance' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.457120
# DeepLift_mean               0.262067
# InputXGradient_L2           0.455696
# InputXGradient_mean         0.250785
# IntegratedGradients_L2      0.387659
# IntegratedGradients_mean    0.326542
# Occlusion                   0.498807
# Occlusion_abs               0.532635
# Saliency_L2                 0.455947
# Saliency_mean               0.304219
# ShapleyValue                0.170739
# attention_flow              0.271031
# attention_rollout           0.332236
# raw_attention               0.337411
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_balance' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.457734
# DeepLift_mean               0.277161
# InputXGradient_L2           0.451466
# InputXGradient_mean         0.245177
# IntegratedGradients_L2      0.416335
# IntegratedGradients_mean    0.331641
# Occlusion                   0.444128
# Occlusion_abs               0.530281
# Saliency_L2                 0.454874
# Saliency_mean               0.272294
# ShapleyValue                0.189741
# attention_flow              0.273402
# attention_rollout           0.355963
# raw_attention               0.378095
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_class_balance' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.430882
# DeepLift_mean               0.234941
# InputXGradient_L2           0.434452
# InputXGradient_mean         0.321079
# IntegratedGradients_L2      0.400168
# IntegratedGradients_mean    0.340933
# Occlusion                   0.489697
# Occlusion_abs               0.492224
# Saliency_L2                 0.432987
# Saliency_mean               0.327528
# ShapleyValue                0.141300
# attention_flow              0.288598
# attention_rollout           0.377589
# raw_attention               0.387342
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'group_class_balance' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.470389
# DeepLift_mean               0.301791
# InputXGradient_L2           0.465825
# InputXGradient_mean         0.368923
# IntegratedGradients_L2      0.404627
# IntegratedGradients_mean    0.316922
# Occlusion                   0.455356
# Occlusion_abs               0.468839
# Saliency_L2                 0.466109
# Saliency_mean               0.324611
# ShapleyValue                0.131632
# attention_flow              0.304393
# attention_rollout           0.352688
# raw_attention               0.344925
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'cda' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.364569
# DeepLift_mean               0.263060
# InputXGradient_L2           0.363217
# InputXGradient_mean         0.311530
# IntegratedGradients_L2      0.277603
# IntegratedGradients_mean    0.265075
# Occlusion                   0.385747
# Occlusion_abs               0.405717
# Saliency_L2                 0.363982
# Saliency_mean               0.284304
# ShapleyValue                0.127681
# attention_flow              0.179968
# attention_rollout           0.243618
# raw_attention               0.220894
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'cda' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.312613
# DeepLift_mean               0.221227
# InputXGradient_L2           0.318671
# InputXGradient_mean         0.264305
# IntegratedGradients_L2      0.262147
# IntegratedGradients_mean    0.200321
# Occlusion                   0.384684
# Occlusion_abs               0.354235
# Saliency_L2                 0.319779
# Saliency_mean               0.293879
# ShapleyValue                0.126345
# attention_flow              0.156811
# attention_rollout           0.159489
# raw_attention               0.157803
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'dropout' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.416757
# DeepLift_mean               0.255181
# InputXGradient_L2           0.408414
# InputXGradient_mean         0.282707
# IntegratedGradients_L2      0.343098
# IntegratedGradients_mean    0.289870
# Occlusion                   0.481705
# Occlusion_abs               0.480410
# Saliency_L2                 0.410951
# Saliency_mean               0.317481
# ShapleyValue                0.140884
# attention_flow              0.228147
# attention_rollout           0.298065
# raw_attention               0.302334
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'dropout' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.499823
# DeepLift_mean               0.261850
# InputXGradient_L2           0.483851
# InputXGradient_mean         0.330779
# IntegratedGradients_L2      0.429285
# IntegratedGradients_mean    0.277562
# Occlusion                   0.516911
# Occlusion_abs               0.549495
# Saliency_L2                 0.483644
# Saliency_mean               0.344668
# ShapleyValue                0.181374
# attention_flow              0.318164
# attention_rollout           0.366625
# raw_attention               0.371142
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'attention_entropy' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.375151
# DeepLift_mean               0.187031
# InputXGradient_L2           0.370284
# InputXGradient_mean         0.268409
# IntegratedGradients_L2      0.335004
# IntegratedGradients_mean    0.267615
# Occlusion                   0.506221
# Occlusion_abs               0.500648
# Saliency_L2                 0.371278
# Saliency_mean               0.291496
# ShapleyValue                0.138154
# attention_flow              0.221848
# attention_rollout           0.269448
# raw_attention               0.283534
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'attention_entropy' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.457182
# DeepLift_mean               0.239850
# InputXGradient_L2           0.444827
# InputXGradient_mean         0.282194
# IntegratedGradients_L2      0.410495
# IntegratedGradients_mean    0.293500
# Occlusion                   0.461163
# Occlusion_abs               0.492144
# Saliency_L2                 0.443325
# Saliency_mean               0.292758
# ShapleyValue                0.180236
# attention_flow              0.301649
# attention_rollout           0.338312
# raw_attention               0.342257
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'causal_debias' and training type 'all axes':
# explanation_method
# DeepLift_L2                 0.455088
# DeepLift_mean               0.213291
# InputXGradient_L2           0.444268
# InputXGradient_mean         0.264537
# IntegratedGradients_L2      0.398200
# IntegratedGradients_mean    0.329340
# Occlusion                   0.520843
# Occlusion_abs               0.543946
# Saliency_L2                 0.446751
# Saliency_mean               0.296614
# ShapleyValue                0.171559
# attention_flow              0.210796
# attention_rollout           0.256585
# raw_attention               0.268775
# Name: correlation, dtype: float64
#
# Average correlation for debiasing method 'causal_debias' and training type 'one axis':
# explanation_method
# DeepLift_L2                 0.524004
# DeepLift_mean               0.268394
# InputXGradient_L2           0.523387
# InputXGradient_mean         0.289384
# IntegratedGradients_L2      0.462325
# IntegratedGradients_mean    0.321774
# Occlusion                   0.491872
# Occlusion_abs               0.595122
# Saliency_L2                 0.527502
# Saliency_mean               0.252256
# ShapleyValue                0.154700
# attention_flow              0.335695
# attention_rollout           0.386198
# raw_attention               0.408254
# Name: correlation, dtype: float64
