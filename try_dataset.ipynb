# %%
from utils.dataset_utils import *
from utils.vocabulary import *
bias_type="religion"
datasets = load_subsets_for_fairness_explainability("jigsaw", "train", split_ratio=None, bias_type=bias_type)
print(f"Dataset for {bias_type}:")
print(datasets)
# Out:
# Dataset for religion:
# {'christian': Dataset({
#     features: ['text', 'label'],
#     num_rows: 20953
# }), 'muslim': Dataset({
#     features: ['text', 'label'],
#     num_rows: 15335
# }), 'jewish': Dataset({
#     features: ['text', 'label'],
#     num_rows: 4326
# })}

# %%
# find 10 examples from black subset whose label is 1
for i in range(100):
    if datasets["jewish"]["label"][i] == 0:
        print(datasets["jewish"]["text"][i])
        print("===========")
# Out:
# that is a terrible, heart-wrenching, and scary live feed. fry rambling about altering dna, needing some time with his blanket, and fiore trying to pray him out only for fry to announce he is a messianic jew. this mentally ill kid has been a pawn of the others the whole time, and now he is alone. he clearly is incapable of making a good decision about his future, and the presence of guns means no one can help him.
# ...
# and this isn't my grandfather's america, willing to be led by the nose through the horrors of the middle east by israel's right wing t0 armageddon. well, i'm not.
# ...

# %%
from utils.dataset_utils import *
from utils.vocabulary import *
for bias_type in SOCIAL_GROUPS:
    datasets = load_subsets_for_fairness_explainability("jigsaw", "val", split_ratio=None, bias_type=bias_type)
    print(f"Dataset for {bias_type}:")
    print(datasets)
# Out:
# Dataset for gender:
# {'female': Dataset({
#     features: ['text', 'label'],
#     num_rows: 1002
# }), 'male': Dataset({
#     features: ['text', 'label'],
#     num_rows: 1003
# })}
# Dataset for race:
# {'black': Dataset({
#     features: ['text', 'label'],
#     num_rows: 385
# }), 'white': Dataset({
#     features: ['text', 'label'],
#     num_rows: 876
# })}
# Dataset for religion:
# {'christian': Dataset({
#     features: ['text', 'label'],
#     num_rows: 1069
# }), 'muslim': Dataset({
#     features: ['text', 'label'],
#     num_rows: 724
# }), 'jewish': Dataset({
#     features: ['text', 'label'],
#     num_rows: 265
# })}

# %%
from utils.dataset_utils import *
from utils.vocabulary import *
for bias_type in SOCIAL_GROUPS:
    datasets = load_subsets_for_fairness_explainability("jigsaw", "train", split_ratio=None, bias_type=bias_type)
    print(f"Dataset for {bias_type}:")
    print(datasets)
# Out:
# Dataset for gender:
# {'female': Dataset({
#     features: ['text', 'label'],
#     num_rows: 21166
# }), 'male': Dataset({
#     features: ['text', 'label'],
#     num_rows: 17995
# })}
# Dataset for race:
# {'black': Dataset({
#     features: ['text', 'label'],
#     num_rows: 7871
# }), 'white': Dataset({
#     features: ['text', 'label'],
#     num_rows: 17786
# })}
# Dataset for religion:
# {'christian': Dataset({
#     features: ['text', 'label'],
#     num_rows: 20953
# }), 'muslim': Dataset({
#     features: ['text', 'label'],
#     num_rows: 15335
# }), 'jewish': Dataset({
#     features: ['text', 'label'],
#     num_rows: 4326
# })}
