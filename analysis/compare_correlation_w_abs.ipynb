# %%
import os
import json

root_dir = "/scratch/yifwang/new_fairness_x_explainability/encoder_results"
models = ["bert", "roberta", "distilbert"]
bias_types = ["race", "gender", "religion"]
methods = ["Attention", "Saliency", "DeepLift", "InputXGradient", "IntegratedGradients", "Occlusion", "KernelShap"]
debiasing_methods = ["no_debiasing", "group_balance", "group_class_balance", "cda", "dropout", "attention_entropy", "causal_debias"]
training_types = ["all axes", "one axis"]
reliance_keys = ["raw", "max", "len", "norm"]
num_examples = {"race": 2000, "gender": 2000, "religion": 1000}

# %%
data_type = "all" # "race"
correlation_w_abs_dir = f"/nethome/yifwang/fairness_x_explainability/new_fairness_explainability/analysis/correlation_w_abs"
correlation_wo_abs_dir = f"/scratch/yifwang/new_fairness_x_explainability/encoder_results"

correlation_dict = {"debiasing_method": [], "explanation_method": [], "aggregation_method": [], "correlation": [], "reliance_method": []}
bias_type = "race"
model = "bert"


data_token = bias_type
for debiasing_method in debiasing_methods:
    for explanation_method in methods:
        file_path = os.path.join(correlation_wo_abs_dir, f"{model}_civil_{data_token}_{bias_type}_test_{num_examples[bias_type]}", debiasing_method, "correlation", f"correlation_{explanation_method}_{bias_type}_test.json")

        with open(file_path, "r") as f:
            correlation_data = json.load(f)
        for aggregation_method, value in correlation_data.items():
            for reliance_method in reliance_keys:
                correlation_dict["debiasing_method"].append(debiasing_method)
                correlation_dict["aggregation_method"].append(aggregation_method)
                correlation_dict["explanation_method"].append(explanation_method)
                correlation_dict["correlation"].append(value['abs_average'][reliance_method])
                correlation_dict["reliance_method"].append(reliance_method)

        file_path = os.path.join(correlation_w_abs_dir, f"{model}_civil_{data_token}_{bias_type}_test_{num_examples[bias_type]}", debiasing_method, "correlation", f"correlation_{explanation_method}_{bias_type}_test.json")
        with open(file_path, "r") as f:
            correlation_data = json.load(f)
        for aggregation_method, value in correlation_data.items():
            if "L2" in aggregation_method or "attention" in aggregation_method:
                continue
            for reliance_method in reliance_keys:
                correlation_dict["debiasing_method"].append(debiasing_method)
                correlation_dict["explanation_method"].append(explanation_method)
                correlation_dict["aggregation_method"].append(f"{aggregation_method}_abs")
                correlation_dict["correlation"].append(value['abs_average'][reliance_method])
                correlation_dict["reliance_method"].append(reliance_method)

# %%
# convert to a pandas DataFrame
import pandas as pd
correlation_df = pd.DataFrame(correlation_dict)
correlation_df
# Out:
#     debiasing_method explanation_method aggregation_method  correlation  \
# 0       no_debiasing          Attention      raw_attention     0.616991
# 1       no_debiasing          Attention      raw_attention     0.620664
# 2       no_debiasing          Attention      raw_attention     0.432899
# 3       no_debiasing          Attention      raw_attention     0.628654
# 4       no_debiasing          Attention  attention_rollout     0.585958
# ..               ...                ...                ...          ...
# 527    causal_debias         KernelShap       ShapleyValue     0.143727
# 528    causal_debias         KernelShap   ShapleyValue_abs     0.140331
# 529    causal_debias         KernelShap   ShapleyValue_abs     0.094774
# 530    causal_debias         KernelShap   ShapleyValue_abs     0.212852
# 531    causal_debias         KernelShap   ShapleyValue_abs     0.175201
#
#     reliance_method
# 0               raw
# 1               max
# 2               len
# 3              norm
# 4               raw
# ..              ...
# 527            norm
# 528             raw
# 529             max
# 530             len
# 531            norm
#
# [532 rows x 5 columns]

# %%
reliance_method = "raw"
methods_with_directions = ["Saliency", "DeepLift", "InputXGradient", "IntegratedGradients", "Occlusion"]
for debiasing_method in debiasing_methods:
    print("\n\n")
    print(f"Debiasing Method: {debiasing_method}")
    print("=" * 50)
    for explanation_method in methods_with_directions:
        avg_corr_df = correlation_df[(correlation_df["debiasing_method"] == debiasing_method) & (correlation_df["explanation_method"] == explanation_method) & (correlation_df["reliance_method"] == reliance_method)].groupby("aggregation_method")["correlation"].mean().reset_index()
        
        print(avg_corr_df)
        print("\n")
# Out:
# Debiasing Method: no_debiasing
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.495682
# 1      Saliency_mean     0.063675
# 2  Saliency_mean_abs     0.317893
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.501819
# 1      DeepLift_mean     0.060396
# 2  DeepLift_mean_abs     0.260645
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.489937
# 1      InputXGradient_mean     0.296884
# 2  InputXGradient_mean_abs     0.381399
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.566025
# 1      IntegratedGradients_mean     0.453126
# 2  IntegratedGradients_mean_abs     0.510584
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.621426
# 1      Occlusion_abs     0.657727
#
#
#
#
#
# Debiasing Method: group_balance
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.600200
# 1      Saliency_mean     0.179951
# 2  Saliency_mean_abs     0.428645
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.555252
# 1      DeepLift_mean     0.192697
# 2  DeepLift_mean_abs     0.400419
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.600892
# 1      InputXGradient_mean     0.369029
# 2  InputXGradient_mean_abs     0.461593
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.539445
# 1      IntegratedGradients_mean     0.408826
# 2  IntegratedGradients_mean_abs     0.494874
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.673397
# 1      Occlusion_abs     0.723203
#
#
#
#
#
# Debiasing Method: group_class_balance
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.526190
# 1      Saliency_mean     0.145694
# 2  Saliency_mean_abs     0.370112
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.544273
# 1      DeepLift_mean     0.198431
# 2  DeepLift_mean_abs     0.396167
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.518672
# 1      InputXGradient_mean     0.164923
# 2  InputXGradient_mean_abs     0.389611
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.400976
# 1      IntegratedGradients_mean     0.231068
# 2  IntegratedGradients_mean_abs     0.261739
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.606758
# 1      Occlusion_abs     0.651349
#
#
#
#
#
# Debiasing Method: cda
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.069178
# 1      Saliency_mean     0.058643
# 2  Saliency_mean_abs     0.062054
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.071729
# 1      DeepLift_mean     0.071841
# 2  DeepLift_mean_abs     0.044572
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.059966
# 1      InputXGradient_mean     0.091869
# 2  InputXGradient_mean_abs     0.069049
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.059002
# 1      IntegratedGradients_mean     0.062585
# 2  IntegratedGradients_mean_abs     0.080120
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.074688
# 1      Occlusion_abs     0.084434
#
#
#
#
#
# Debiasing Method: dropout
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.495890
# 1      Saliency_mean     0.047941
# 2  Saliency_mean_abs     0.284416
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.560325
# 1      DeepLift_mean     0.086648
# 2  DeepLift_mean_abs     0.340911
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.492075
# 1      InputXGradient_mean     0.328142
# 2  InputXGradient_mean_abs     0.380564
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.492434
# 1      IntegratedGradients_mean     0.424441
# 2  IntegratedGradients_mean_abs     0.453171
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.681613
# 1      Occlusion_abs     0.707084
#
#
#
#
#
# Debiasing Method: attention_entropy
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.479052
# 1      Saliency_mean     0.084555
# 2  Saliency_mean_abs     0.264296
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.558445
# 1      DeepLift_mean     0.080730
# 2  DeepLift_mean_abs     0.309499
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.474313
# 1      InputXGradient_mean     0.277736
# 2  InputXGradient_mean_abs     0.360037
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.468397
# 1      IntegratedGradients_mean     0.348145
# 2  IntegratedGradients_mean_abs     0.397388
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.629262
# 1      Occlusion_abs     0.667053
#
#
#
#
#
# Debiasing Method: causal_debias
# ==================================================
#   aggregation_method  correlation
# 0        Saliency_L2     0.582051
# 1      Saliency_mean     0.193679
# 2  Saliency_mean_abs     0.403594
#
#
#   aggregation_method  correlation
# 0        DeepLift_L2     0.607646
# 1      DeepLift_mean     0.145849
# 2  DeepLift_mean_abs     0.410790
#
#
#         aggregation_method  correlation
# 0        InputXGradient_L2     0.569479
# 1      InputXGradient_mean     0.215965
# 2  InputXGradient_mean_abs     0.402346
#
#
#              aggregation_method  correlation
# 0        IntegratedGradients_L2     0.483822
# 1      IntegratedGradients_mean     0.192341
# 2  IntegratedGradients_mean_abs     0.309877
#
#
#   aggregation_method  correlation
# 0          Occlusion     0.522365
# 1      Occlusion_abs     0.684551
